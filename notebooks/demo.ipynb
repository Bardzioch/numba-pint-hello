# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🚀 Demo pakietu `numpi_hello`\n",
    "\n",
    "Projekt łączy akcelerację obliczeń za pomocą **Numby** oraz obsługę jednostek fizycznych dzięki **Pintowi**."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Tę komórkę uruchom **tylko w Google Colab**.\n",
    "# W Binderze pakiet jest już zainstalowany, więc możesz ją pominąć.\n",
    "import sys\n",
    "if 'google.colab' in sys.modules:\n",
    "    !pip install git+https://github.com/Bardzioch/numba-pint-hello.git\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from numpi_hello import hello_numba, hello_pint, __version__\n",
    "print(f\"Wersja pakietu: {__version__}\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Test Numby: suma kwadratów liczb 0..9\n",
    "result = hello_numba(10)\n",
    "print(f\"Suma kwadratów dla n=10: {result}\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Test Pinta: konwersja prędkości\n",
    "print(hello_pint(100))\n",
    "print(hello_pint(36))"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.10.0"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
